# %%
from azureml.core import Experiment
from azureml.core.compute import AmlCompute, ComputeTarget
from azureml.core.datastore import Datastore
from azureml.core.runconfig import CondaDependencies, RunConfiguration
from azureml.data.data_reference import DataReference
from azureml.pipeline.core import Pipeline, PipelineData
from azureml.pipeline.steps import PythonScriptStep
from azureml.core import Workspace, Experiment
from azureml.pipeline.core import OutputPortBinding
import pandas as pd
import azureml
from loader import reader_csv
import io

# %%
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication(tenant_id="3b920f4d-d9b6-41a0-927e-89d6664219bc")

ws = Workspace(subscription_id="4ca4328f-9db7-4cbc-ae4b-380b5a441a58",
               resource_group="mlservice",
               workspace_name="mlservice",
               auth=interactive_auth)

# %% [markdown]
# # Cluster's list on the subscriptuion

# %%
cts = ws.compute_targets
for ct in cts:
    print(ct)
# Out:
# spar

# %% [markdown]
# # Get a list of objects for prediction

# %%
switch_on = reader_csv('spardata', r'switch_on/stores.csv' )
stores = switch_on['ObjCode'].to_list()

# %% [markdown]
# # Deleting unnecessary pipelines

# %%
from azureml.pipeline.core import PublishedPipeline
published_pipeline = PublishedPipeline.get(ws, '{}'.format('bd4c6391-6b73-40ba-87dd-e3ba5ed9a638'))
published_pipeline.disable()

# %% [markdown]
# # Pipeline creation

# %%
compute_target = AmlCompute(ws, "spar")

conda_dependencies = CondaDependencies.create(
    pip_packages=["boto3==1.21.15", "pandas==1.4.1", "catboost==1.2",  "pyjwt==1.7.1", "xlrd", 'requests'], python_version="3.11"
) # "catboost",
run_config = RunConfiguration(conda_dependencies=conda_dependencies)
run_config.environment.docker.enabled = True
run_config.source_directory_data_store = "workspaceblobstore"



steps = []


score_preparing = PythonScriptStep(allow_reuse=False,
    name="preparing",
    script_name="preparing.py",
    compute_target=compute_target,
    runconfig=run_config,
    source_directory = "preparing")

score_temp_promo_deleting = PythonScriptStep(allow_reuse=False,
    name="promo_deleting",
    script_name="temp_promo_deleting.py",
    compute_target=compute_target,
    runconfig=run_config,
    source_directory = "temp_promo_deleting")


for stores in stores_list:
    
    score_step = PythonScriptStep(allow_reuse=False,
        name=f"prediction_scoring_{stores}",
        script_name="prediction1.py",
        arguments=[ "--stores", "{}".format(stores)],
        compute_target=compute_target,
        runconfig=run_config,
        source_directory = "prediction")
    

    
    score_step1 = PythonScriptStep(allow_reuse=False,
        name="discount_scoring",
        script_name="discount_updating.py",
        arguments=[ "--stores", "{}".format(stores)],
        compute_target=compute_target,
        runconfig=run_config,
        source_directory = "discount_updating")
    
    score_step1.run_after(score_preparing)
    score_step.run_after(score_step1)
    score_temp_promo_deleting.run_after(score_step)

steps.append(score_temp_promo_deleting)

# %%
pipeline = Pipeline(workspace=ws, steps=steps)

# %%
len(steps)
# Out:
# 1

# %% [markdown]
# # Публикация пайплайна

# %%
pipeline_name = "pipeline_25_09_2023"
print(pipeline_name)

published_pipeline = pipeline.publish(
    name=pipeline_name,
    description=pipeline_name)
print("Newly published pipeline id: {}".format(published_pipeline.id))
# Out:
# pipeline_25_09_2023
# Created step promo_deleting [84780082][cc97b1f7-ed78-4ddb-97b0-65bb659f3d9a], (This step will run and generate new outputs)
# Created step prediction_scoring_1553 [7d413967][bbf26366-c781-4c55-b9ee-b4a6c913387b], (This step will run and generate new outputs)
# Created step discount_scoring [83a70207][d45b71d5-b064-49b0-96ad-c9c8a5e0f76d], (This step will run and generate new outputs)
# Created step preparing [2ba7577d][783691c4-c522-473f-92a4-17ebc26ed4b1], (This step will run and generate new outputs)
# Created step prediction_scoring_1554 [49f38c77][687cc51a-60c4-4cc9-b83b-50b9c7eaae3e], (This step will run and generate new outputs)
# Created step discount_scoring [c7f8f3d9][8aa96045-a2e5-4d3c-bf6d-f8b13ae3c688], (This step will run and generate new outputs)
# Created step prediction_scoring_1567 [bcb509bd][618758f5-c645-4d23-9b7b-7df5a2bc6b6a], (This step will run and generate new outputs)
# Created step discount_scoring [239241b7][25a9d008-334b-4510-b54b-cf947318df00], (This step will run and generate new outputs)
# Created step prediction_scoring_1568 [8ab2c527][5f738145-4b47-4631-9f6d-f97e50d665c3], (This step will run and generate new outputs)
# Created step discount_scoring [3dbcfbc0][60ff68ce-b5b1-4526-84bd-293eeab3c045], (This step will run and generate new outputs)
# Created step prediction_scoring_1593 [fd27126f][a6c5035f-0aa2-4eb2-abb7-0c7df6c7f9b6], (This step will run and generate new outputs)
# Created step discount_scoring [c109099f][3b1a0167-a497-4be2-abcb-51b69a043575], (This step will run and generate new outputs)
# Created step prediction_scoring_1594 [f51a2ac1][e15197b0-4a14-421f-82b7-b2485572a3a0], (This step will run and generate new outputs)
# Created step discount_scoring [a4a22b40][ae7f96ce-d514-42b1-be19-b537f346a17b], (This step will run and generate new outputs)
# Created step prediction_scoring_1595 [39008d8b][be94bf92-2ec4-4b3d-bc0b-67b1689a0acc], (This step will run and generate new outputs)
# Created step discount_scoring [8ced40d9][187091ac-ac86-4742-b054-0c7ecc550477], (This step will run and generate new outputs)
# Created step prediction_scoring_1596 [d79bb226][5addd69d-8d57-4ff5-af1f-645653c2b259], (This step will run and generate new outputs)
# Created step discount_scoring [91982bf6][f04961cd-fbd2-441d-8879-dbd129158113], (This step will run and generate new outputs)
# Created step prediction_scoring_1338 [f83d17af][999503eb-a519-4eb8-8caa-015160b298a5], (This step will run and generate new outputs)
# Created step discount_scoring [c1bb39c1][198d1fd7-d26a-480b-b3b4-9447335b47a4], (This step will run and generate new outputs)
# Created step prediction_scoring_1346 [344b3245][c528f4d8-e3d3-4681-b554-d247f19afb7d], (This step will run and generate new outputs)
# Created step discount_scoring [312bd9f1][77a7d7cd-3ed8-4938-a574-adad360ab447], (This step will run and generate new outputs)
# Created step prediction_scoring_1347 [d466fd9d][0386adad-4e43-428c-8e03-33a514d558a6], (This step will run and generate new outputs)
# Created step discount_scoring [c427a826][7da5b1d1-3edd-4fc7-beeb-a92af2279c9c], (This step will run and generate new outputs)
# Created step prediction_scoring_1348 [23045ee2][7b048da4-ea60-4370-adef-14676638fc3f], (This step will run and generate new outputs)
# Created step discount_scoring [679656c3][4f32d5c6-b1f3-47a5-bb1e-715f3a6b2a7e], (This step will run and generate new outputs)
# Created step prediction_scoring_1349 [7ece6bf8][8f6d33bb-5cc9-479d-90dd-74cd2ee72cb7], (This step will run and generate new outputs)
# Created step discount_scoring [0dcc94d7][851dcf49-20c6-47b3-9ef7-67db46fa5a95], (This step will run and generate new outputs)
# Created step prediction_scoring_1351 [7eb8d58a][1946460a-96f0-4490-b5a1-ac19904f7c79], (This step will run and generate new outputs)
# Created step discount_scoring [a9c117a9][afe2568d-620a-431e-a577-f64bfb494e84], (This step will run and generate new outputs)
# Created step prediction_scoring_1352 [992d0d29][2e5f665d-71b1-4ae6-a3fd-8f33ea3948c9], (This step will run and generate new outputs)
# Created step discount_scoring [770c2066][59fee0c5-94c3-42c5-a82f-4ede61b3404c], (This step will run and generate new outputs)
# Created step prediction_scoring_1353 [32cc0fac][31b90aca-802f-4aab-9e81-6e13b0589430], (This step will run and generate new outputs)
# Created step discount_scoring [3eb0de70][1faaabcc-2b04-46e9-9355-c8237ad1219c], (This step will run and generate new outputs)
# Created step prediction_scoring_1354 [47ff5644][d29cb77e-26ba-42aa-adcc-69f44abb3eb5], (This step will run and generate new outputs)
# Created step discount_scoring [bf44f584][3018f864-aea5-499b-bf15-3160b76b9915], (This step will run and generate new outputs)
# Created step prediction_scoring_1612 [87105e37][08647519-ea72-41e1-b540-02b2ffd3ab1d], (This step will run and generate new outputs)
# Created step discount_scoring [78b2bf76][7cd220c4-701e-40b6-9a7c-8ac3a0a9063a], (This step will run and generate new outputs)
# Created step prediction_scoring_1613 [b6733532][bd6dfb51-11e9-4482-a458-b2ce3f5868c8], (This step will run and generate new outputs)
# Created step discount_scoring [54fcc8a2][59c6496a-f145-4ada-90de-4df0759d83c9], (This step will run and generate new outputs)
# Created step prediction_scoring_1356 [77937d2b][abe0286a-1248-4368-9b5e-12ceb5ac37f9], (This step will run and generate new outputs)
# Created step discount_scoring [81f90efc][50392a87-ab88-4b5c-8837-78a61da36ebc], (This step will run and generate new outputs)
# Created step prediction_scoring_1358 [368dd499][4ddae14c-ab86-4d05-843f-27f55786d53d], (This step will run and generate new outputs)
# Created step discount_scoring [67bb3a54][c22c8f32-9049-47bf-83ac-febba83bdb92], (This step will run and generate new outputs)Created step prediction_scoring_1359 [7ca8581b][a0698e61-a9a0-4c4c-b38a-5a10b4f2dd27], (This step will run and generate new outputs)
# Created step discount_scoring [0b5aa249][b53ea5d3-23ec-46eb-904e-800c85c8cf73], (This step will run and generate new outputs)
# Created step prediction_scoring_1360 [31f403fa][d661f09e-5f3e-47ee-8a9b-e3345464055e], (This step will run and generate new outputs)
# Created step discount_scoring [dbbf344a][1af699d8-65a5-4003-a95b-402e98aea2ce], (This step will run and generate new outputs)
# Created step prediction_scoring_1361 [c3f19194][6b924b2c-749d-4304-af47-d8d337bb064d], (This step will run and generate new outputs)
# Created step discount_scoring [76e5a221][1ee647b1-04f2-4b83-9aac-9a82eef45676], (This step will run and generate new outputs)
# Created step prediction_scoring_1370 [8dac5124][16e042fa-f3fd-4f1e-a27f-1e152a561b07], (This step will run and generate new outputs)
# Created step discount_scoring [83c56aeb][2901935f-4fe1-48d0-9c44-a1033a42aec4], (This step will run and generate new outputs)
# Created step prediction_scoring_1371 [3d604b81][5a68d5d7-5ae3-4e4f-83a6-717141006750], (This step will run and generate new outputs)
# Created step discount_scoring [627f5c3d][f961de21-b680-41d0-9273-8a627643b36f], (This step will run and generate new outputs)
# Created step prediction_scoring_1372 [d1c4d85d][45ac5a01-8797-4996-a5fc-b2b58cfc9bf0], (This step will run and generate new outputs)
# Created step discount_scoring [730e4c87][8b2aa7de-fd99-45c5-9845-ee6fd42b77c6], (This step will run and generate new outputs)
# Created step prediction_scoring_1373 [43db786d][8475261b-61b3-484a-be1c-f74a8bdb7804], (This step will run and generate new outputs)
# Created step discount_scoring [32be34b0][2fc23c3a-0a23-48d8-9f5f-d8835b0846c5], (This step will run and generate new outputs)
# Created step prediction_scoring_1374 [0e349f3c][9c7d7a8c-6cb4-4fad-b43d-5b4e230d72fb], (This step will run and generate new outputs)
# Created step discount_scoring [dcc3caa3][7b9ddada-65cd-49ff-949a-2ed2a70c0a7b], (This step will run and generate new outputs)
# Created step prediction_scoring_1375 [5e401b34][6ca87abf-dcc5-48a5-a1cb-087d6f186053], (This step will run and generate new outputs)Created step discount_scoring [d46a427a][17f34111-45bf-457d-a0c7-617f5b279f17], (This step will run and generate new outputs)
#
# Created step prediction_scoring_1378 [84ef8a17][41faf65e-a966-47f4-ac11-b9b6813015f0], (This step will run and generate new outputs)Created step discount_scoring [1bcc8c46][d62a9972-cecd-46bd-a822-856dd4d62f30], (This step will run and generate new outputs)
# Created step prediction_scoring_1379 [9359c476][dc5ab8af-806b-49fa-9251-c19ccad80651], (This step will run and generate new outputs)
# Created step discount_scoring [d567a486][db1eeeba-60cc-48d9-9a38-8e4015bc4c04], (This step will run and generate new outputs)
# Created step prediction_scoring_1380 [37420860][66d356ee-ca14-4f05-acb9-675dc5a30072], (This step will run and generate new outputs)
#
# Created step discount_scoring [b4a619f9][22fecbe5-579b-4b98-9fc4-33d6facc6fcc], (This step will run and generate new outputs)
# Created step prediction_scoring_1381 [27807913][731f1317-65d4-4c1c-878b-c5a4631a4760], (This step will run and generate new outputs)
# Created step discount_scoring [45c2e244][6f4cddba-20b1-4b71-a4e7-433fe8d1c7e2], (This step will run and generate new outputs)Created step prediction_scoring_1382 [84903317][fec1e8a4-5708-480d-833d-b38a00909ed6], (This step will run and generate new outputs)
# Created step discount_scoring [a99b338d][bf09f3f6-1657-4a92-bace-75efd3eea2bd], (This step will run and generate new outputs)
# Created step prediction_scoring_1384 [8adf8135][86edcad2-99e0-4f0b-b43f-8368db514606], (This step will run and generate new outputs)
# Created step discount_scoring [c37c477b][a83174e1-bbf1-4c3d-87a0-fa88796f17be], (This step will run and generate new outputs)
# Created step prediction_scoring_1385 [9bd8cc61][6c6617fa-8575-4d6c-98aa-55d57c2d54a8], (This step will run and generate new outputs)
# Created step discount_scoring [a6158aa5][cf935399-ec17-4a30-af4e-8bd03f9059ad], (This step will run and generate new outputs)
# Created step prediction_scoring_1386 [b76f62b8][d6979a6f-104f-44d9-8673-c0d2f3689653], (This step will run and generate new outputs)
# Created step discount_scoring [b3ce9b11][aade2291-8185-4214-b118-5bbd46377168], (This step will run and generate new outputs)
# Created step prediction_scoring_1388 [a15da3ba][4288e013-e665-4aca-a180-2c6392fe40dd], (This step will run and generate new outputs)
# Created step discount_scoring [6c2ea7e6][b3369e68-dc24-425c-b8ca-5e2e8964f4e8], (This step will run and generate new outputs)
# Created step prediction_scoring_1393 [fe95adce][9c927cf7-5300-469e-b8f4-51d4a79c3d3e], (This step will run and generate new outputs)
# Created step discount_scoring [a57269fa][1411ed08-08b1-4fbf-ac08-e6cdc2733d57], (This step will run and generate new outputs)
# Created step prediction_scoring_1395 [113dfe14][ddd5ab6d-2e27-4c0e-83c8-73a2dc0d79bf], (This step will run and generate new outputs)
# Created step discount_scoring [aeb0f3f4][7d7c9e5c-eedd-479b-8645-0fb027e8ac2f], (This step will run and generate new outputs)
# Created step prediction_scoring_1396 [820fcbb1][dd919413-fe30-4e1c-a872-17c57fe2b911], (This step will run and generate new outputs)
# Created step discount_scoring [d6438d55][3e0bee79-8c95-47e9-af81-83eeeddf49b3], (This step will run and generate new outputs)
# Created step prediction_scoring_1397 [6759e9a7][d4ce8949-47fa-4a43-bc79-204da0f3be31], (This step will run and generate new outputs)
# Created step discount_scoring [7bc0b28a][8e6568c8-51d2-4f5a-b8fb-4077ffa055e4], (This step will run and generate new outputs)
# Created step prediction_scoring_1398 [22b9098e][567f5ec9-1e1c-4e80-bc57-b09b5438504f], (This step will run and generate new outputs)
# Created step discount_scoring [645ff79e][3f8d5810-6b91-4a3e-a63b-5fb9a480e9ea], (This step will run and generate new outputs)
# Created step prediction_scoring_1399 [20cf1215][d54795b8-4a6d-48d2-b95c-4045f4275938], (This step will run and generate new outputs)
# Created step discount_scoring [8fc130c0][5be87bf1-f959-41bb-ba55-cd75f0e206d6], (This step will run and generate new outputs)
# Created step prediction_scoring_1403 [15e9c65c][30fbc6a3-18f7-456a-a67b-c7cc5297b071], (This step will run and generate new outputs)
# Created step discount_scoring [d73a78b0][2306534e-7b8b-44ff-a106-df01a7153d83], (This step will run and generate new outputs)
# Created step prediction_scoring_1404 [a24cd13a][0a9c43d1-3dbf-47dd-bc36-b964c1d6a257], (This step will run and generate new outputs)
# Created step discount_scoring [fe0c1e81][717995f7-ed70-4f77-a76a-ae1e7103994c], (This step will run and generate new outputs)
# Created step prediction_scoring_1405 [e158c8a8][cbeabc18-308c-4f3b-ae26-309ecc8c0156], (This step will run and generate new outputs)
# Created step discount_scoring [e31bb316][b1a96af8-1e00-42a3-8d66-ffae73e14a05], (This step will run and generate new outputs)
# Created step prediction_scoring_1407 [311d5d01][cc980a1d-8931-49aa-8399-61bbaf4a5509], (This step will run and generate new outputs)Created step discount_scoring [0c4b659e][91bc44e7-45ed-45f6-8800-ed37453af8c2], (This step will run and generate new outputs)Created step prediction_scoring_1411 [b013f9ff][85f13f85-d455-4b46-ad0e-6d922a89bb2d], (This step will run and generate new outputs)
# Created step discount_scoring [9d7a781a][847320fe-418e-4340-8fe8-ab4e42160db6], (This step will run and generate new outputs)
# Created step prediction_scoring_1412 [1688cf5e][996c1aa9-9c40-435d-9b9c-6b6cdb54d4bc], (This step will run and generate new outputs)
# Created step discount_scoring [e0aa7f7a][3b7f4050-dae7-47ac-9efa-fe1a0bf7c4db], (This step will run and generate new outputs)
# Created step prediction_scoring_1413 [cee33f44][93c14b06-3f88-4058-ad74-9c96b9e80a27], (This step will run and generate new outputs)
# Created step discount_scoring [9cf93b09][7ede2727-bb2e-4884-b908-bbdd09f3b86f], (This step will run and generate new outputs)
# Created step prediction_scoring_1414 [b7223a9c][cb1ef40d-a803-4f45-be3c-6f0dc255c219], (This step will run and generate new outputs)
# Created step discount_scoring [2c876a24][fdee1dc4-3d87-447a-9067-f256f515e6d7], (This step will run and generate new outputs)
# Created step prediction_scoring_1671 [f1ba0dbd][90a1fd32-b5dd-4dc4-b667-a2523135fffc], (This step will run and generate new outputs)
# Created step discount_scoring [d5b3292f][7d06771c-b3d4-4c1e-bc17-31159880e8cd], (This step will run and generate new outputs)Created step prediction_scoring_1415 [a3822a0d][08182a79-901e-4050-b6e1-688f6360fde3], (This step will run and generate new outputs)
# Created step discount_scoring [ac25e7d1][92203bd7-837d-4651-a8eb-1f42b3683cd8], (This step will run and generate new outputs)
#
#
# Created step prediction_scoring_1417 [7024b072][b15aa7cd-0819-4710-b725-94b342396b68], (This step will run and generate new outputs)
# Created step discount_scoring [828931cd][7efdc766-4a1f-4266-b68a-8119acb0f082], (This step will run and generate new outputs)
#
# Created step prediction_scoring_1418 [b8802223][65685ee3-4447-479a-b73b-2c223ce118e3], (This step will run and generate new outputs)
# Created step discount_scoring [5b1228d7][dd2aa2b9-9a4c-4be2-8b5f-7f16cb0f1062], (This step will run and generate new outputs)Created step prediction_scoring_1429 [ece1a6b6][a19debc5-1e85-4dbf-b6cc-5d0ad4c0f1ab], (This step will run and generate new outputs)
# Created step discount_scoring [17b25816][29296a5a-7fa5-4a3f-8a4c-9493e4f2a7ca], (This step will run and generate new outputs)
# Created step prediction_scoring_1430 [423e0df7][b0de45de-f227-4162-9b57-1648f2c625a2], (This step will run and generate new outputs)
# Created step discount_scoring [83178bb3][1e083c52-22a4-4674-97e1-95c72afb3110], (This step will run and generate new outputs)
# Created step prediction_scoring_1431 [84539511][38201fe1-07d2-42a6-a606-b65d091c4831], (This step will run and generate new outputs)
# Created step discount_scoring [95f93cfe][6a1a9963-70e2-4731-80be-9e7ea6fada94], (This step will run and generate new outputs)
# Created step prediction_scoring_1432 [7196de2d][2c09349c-e114-4106-8ac4-a9cbe6c287bf], (This step will run and generate new outputs)
#
# Created step discount_scoring [7f18d7ff][7e67cd65-2227-41a8-8d5c-82926b9aa517], (This step will run and generate new outputs)
# Created step prediction_scoring_1433 [3d1f61ee][4af1796a-f7c3-4b2f-8df6-01dabbb148c9], (This step will run and generate new outputs)
# Created step discount_scoring [c65101f0][29e62de8-ff04-44ad-b86a-05f85d79f35e], (This step will run and generate new outputs)
# Created step prediction_scoring_1434 [a927824d][6c89e618-6eda-4729-926e-070960aa5902], (This step will run and generate new outputs)
# Created step discount_scoring [482fab0e][0831c913-d407-4458-a9f0-732db32630e4], (This step will run and generate new outputs)
# Created step prediction_scoring_1436 [32cd0b6a][6645f70e-9a6e-4f8d-81ea-c78c52251220], (This step will run and generate new outputs)
# Created step discount_scoring [64272ce7][46fac637-4eb3-4519-8937-acaf89d7c6e2], (This step will run and generate new outputs)
# Created step prediction_scoring_1437 [bdb0c060][c5d5359a-b035-4301-b436-f1386db83c9e], (This step will run and generate new outputs)Created step discount_scoring [cf0e1d49][efae231c-bebf-47a7-9279-0ce68e260aa6], (This step will run and generate new outputs)
# Created step prediction_scoring_1438 [eef60dd0][86d5ea7b-0f58-4fcf-b3cb-aaae9e38e1b9], (This step will run and generate new outputs)
# Created step discount_scoring [22b7db03][2f6a2c4a-1fc9-4999-8893-fa0080986243], (This step will run and generate new outputs)
# Created step prediction_scoring_1439 [172995e2][5c8bf9a4-fdb1-40b9-94ef-aae5733ed204], (This step will run and generate new outputs)
#
#
# Created step discount_scoring [4a30d51c][c70cb183-1c0d-4385-b50b-ab5559faac39], (This step will run and generate new outputs)
# Created step prediction_scoring_1442 [8c920ea3][934a6ff1-3ae3-4d78-b02b-efd1094d184c], (This step will run and generate new outputs)
# Created step discount_scoring [f00e796a][a181f31f-3b4a-4983-ad83-e4286a16c134], (This step will run and generate new outputs)
# Created step prediction_scoring_1443 [9709be73][5c7aff05-7569-4d24-b7e2-300247d2d1ec], (This step will run and generate new outputs)
# Created step discount_scoring [1f835a88][a9a16c3e-66f8-4e33-ba94-350b9919ea9a], (This step will run and generate new outputs)Created step prediction_scoring_1444 [ad506569][489bd327-67d9-40f2-937e-876e27b3f4db], (This step will run and generate new outputs)
# Created step discount_scoring [7a308e31][d8b41553-d83e-459a-ad76-db6928362543], (This step will run and generate new outputs)
# Created step prediction_scoring_1445 [bd138795][864291cc-8977-4e0e-ada1-62dee859abfb], (This step will run and generate new outputs)
# Created step discount_scoring [e5820b3d][814a2714-9e13-4153-86af-e4dbf6a6cfb7], (This step will run and generate new outputs)
# Created step prediction_scoring_1464 [ade458c8][ade53d28-3690-4140-8e61-58601de49236], (This step will run and generate new outputs)
# Created step discount_scoring [7968752f][44b5f8c6-3761-4676-82f9-dc841a0e4bce], (This step will run and generate new outputs)
# Created step prediction_scoring_1465 [5c68261f][135f5176-6cb0-4898-80b8-2d297c9416f3], (This step will run and generate new outputs)
# Created step discount_scoring [8759bb83][85697e32-bff5-4740-bf0e-1ddda539bec1], (This step will run and generate new outputs)Created step prediction_scoring_956 [d818dbbd][8479dc37-a5ee-42be-9a1d-0f6ed215b4e6], (This step will run and generate new outputs)Created step discount_scoring [7e0aaed1][48311019-437f-41d3-a495-db3541e27f01], (This step will run and generate new outputs)
# Created step prediction_scoring_957 [f58db2fe][eb1a61c2-1203-47de-b608-0226cc3d9932], (This step will run and generate new outputs)
# Created step discount_scoring [72b4a04a][4f994436-c9d2-4ad5-9b92-83d0870520b7], (This step will run and generate new outputs)
# Created step prediction_scoring_960 [7b498bb6][64161b8e-9856-4675-b97b-8a2eda8e5da3], (This step will run and generate new outputs)
# Created step discount_scoring [55e5a99e][61e00133-a925-4dcd-a9ba-179ed3b8afa4], (This step will run and generate new outputs)
# Created step prediction_scoring_1475 [fc4c576d][1b7f614b-0120-4759-ad36-c113d0f591ea], (This step will run and generate new outputs)
# Created step discount_scoring [9dd3a347][c593e5cb-7163-4b14-aab5-0222a5af225d], (This step will run and generate new outputs)
# Created step prediction_scoring_1476 [b141dbb8][9558c8bf-06a7-4e71-9f1f-568528eef4f7], (This step will run and generate new outputs)
# Created step discount_scoring [13a3a17c][508cf062-ceb1-45e6-9a4e-043664572ee1], (This step will run and generate new outputs)
# Created step prediction_scoring_1477 [9b98d634][874cccac-cb90-4855-9385-38ff8eaabf6f], (This step will run and generate new outputs)
# Created step discount_scoring [84ccc5e7][584988c5-d1e7-47da-b037-1b4f60254eb9], (This step will run and generate new outputs)
# Created step prediction_scoring_1478 [a2fc20b1][070b11fe-fb8d-41b5-99ea-c66341d003d7], (This step will run and generate new outputs)
# Created step discount_scoring [50a70a51][cf13c1c0-87ad-4e50-bf36-60f8fe1e2d7a], (This step will run and generate new outputs)
# Created step prediction_scoring_994 [f49370c8][6f8d8110-a533-43fb-9d3c-49d096bf80a1], (This step will run and generate new outputs)
# Created step discount_scoring [327d700b][1a01c0af-9db7-412c-b95c-4d272fbcb40f], (This step will run and generate new outputs)
# Created step prediction_scoring_1507 [3152a88a][17774fc6-f6a7-4e94-be9c-6683ce0d8027], (This step will run and generate new outputs)
# Created step discount_scoring [6b8c8f52][24fce1e8-54d3-4bb6-9a53-3103376a3c0f], (This step will run and generate new outputs)
# Created step prediction_scoring_1508 [b670e1cd][d14bfdf9-3ce5-451f-9d5c-7f81e9f5ba25], (This step will run and generate new outputs)Created step discount_scoring [6bb72d47][e2721ec0-e152-45da-a651-b6c900f09029], (This step will run and generate new outputs)
# Created step prediction_scoring_1509 [51368fd9][f39b6cec-b610-4a91-a90f-09142a91badc], (This step will run and generate new outputs)
# Created step discount_scoring [81dce3ab][a1b8fe36-fc94-4aa8-9e7c-30c13ed03400], (This step will run and generate new outputs)
# Created step prediction_scoring_1510 [ba054d1d][04469d8e-d49c-4cf5-a656-181a76d54a5d], (This step will run and generate new outputs)
# Created step discount_scoring [b929036d][4d15845e-5d86-406c-a76f-d1319ca3cb7d], (This step will run and generate new outputs)
# Created step prediction_scoring_1511 [e7be0c09][a3ee6f37-3993-4db0-925b-202275e23f45], (This step will run and generate new outputs)
# Created step discount_scoring [46897818][d2276716-3d33-4fb6-9948-7c65aa781912], (This step will run and generate new outputs)
# Created step prediction_scoring_1518 [c51e32a1][c641c072-64ff-474b-b40b-1b220b9e93e8], (This step will run and generate new outputs)
# Created step discount_scoring [79d88079][9e6cf4d4-ebb0-409d-b856-a05611c348ad], (This step will run and generate new outputs)
# Created step prediction_scoring_928 [bed608f8][c80510dc-4177-4fd0-9224-a1ac5686796e], (This step will run and generate new outputs)
#
# Created step discount_scoring [298a0859][c2f32373-7e53-4afd-8f98-d4b6a053e5f2], (This step will run and generate new outputs)
# Created step prediction_scoring_980 [f051f343][ad4252ff-a9ab-4eac-97b6-1bd550da4841], (This step will run and generate new outputs)
# Created step discount_scoring [ba4a1e16][cdb467ed-88c9-4ec6-a260-9852b6bcd065], (This step will run and generate new outputs)
# Created step prediction_scoring_939 [480847e9][de4c39eb-e3e9-49ec-8d40-84528013faeb], (This step will run and generate new outputs)
# Created step discount_scoring [a4a1fe42][06abae0e-14a7-4dde-bb09-b6000b65f6a0], (This step will run and generate new outputs)
# Created step prediction_scoring_938 [c7eadf75][d7f268fb-d8b5-465f-aa95-b63603aef324], (This step will run and generate new outputs)
# Created step discount_scoring [437e4785][85bf7a53-a5b6-47b1-b4b3-bc0fc9676cb5], (This step will run and generate new outputs)
# Created step prediction_scoring_904 [04ebae7f][223fba64-25ae-41fe-aaf3-e3da7ac71a51], (This step will run and generate new outputs)
# Created step discount_scoring [89ec5a10][308408bf-c148-49ad-89ad-ab508bde7826], (This step will run and generate new outputs)
# Created step prediction_scoring_895 [86ddab28][16fd38f3-f4e2-4b10-bdea-52389002cfa7], (This step will run and generate new outputs)
# Created step discount_scoring [8623e3e4][7a9b5908-f20c-44d5-8f63-0b41cf3d9d01], (This step will run and generate new outputs)
# Created step prediction_scoring_885 [630d019d][b14259b8-8ce6-4fc6-810e-0bed008089ef], (This step will run and generate new outputs)
# Created step discount_scoring [fb2fc061][0ce0e7bf-8b31-4008-bfbd-fc51ddc6fa63], (This step will run and generate new outputs)
# Created step prediction_scoring_878 [9b958214][6844870f-066f-45fc-bec1-8307e285f5a8], (This step will run and generate new outputs)
# Created step discount_scoring [ca2991c8][066338ee-2b51-4f7b-9dce-d539e56951ab], (This step will run and generate new outputs)
# Created step prediction_scoring_874 [9e032811][220abb18-4cef-4b0d-93cd-3c4a18449b59], (This step will run and generate new outputs)Created step discount_scoring [5fcb579f][15c9296b-8fc4-4bd6-a166-a7ea55bc6a17], (This step will run and generate new outputs)
# Created step prediction_scoring_873 [aee22aae][61e6f7ad-2c6c-4aaa-a82d-88cfc2a67bb0], (This step will run and generate new outputs)
# Created step discount_scoring [60293cce][2879a2c6-a6c0-424e-b7bb-57cf5ea551e6], (This step will run and generate new outputs)
# Created step prediction_scoring_862 [a543a66c][f5b2c0ed-24f5-4763-b68e-7672d40b08f9], (This step will run and generate new outputs)
# Created step discount_scoring [63fb6a99][6c0f30b5-a8d2-43b4-8363-d67841316345], (This step will run and generate new outputs)
#
# Created step prediction_scoring_856 [9c6bee8d][a1746bea-3e37-46d6-a585-3e9869a15a04], (This step will run and generate new outputs)Created step discount_scoring [970f22cb][72ca8f95-bb17-42fd-8097-0e0144a33f22], (This step will run and generate new outputs)Created step prediction_scoring_860 [e08ecfd7][e9d03cae-0030-49fd-ba64-cf7d78f179e8], (This step will run and generate new outputs)
# Created step discount_scoring [24494585][14f06823-95fb-42cb-aed2-db52ddde34d7], (This step will run and generate new outputs)
# Created step prediction_scoring_846 [1d44ad93][916839ab-e374-412c-88e9-766a6a86a41e], (This step will run and generate new outputs)
# Created step discount_scoring [b72f858c][0dc11c42-aac7-4feb-8871-adacff6b88bd], (This step will run and generate new outputs)
#
#
# Created step prediction_scoring_848 [02e98afb][ec3d121b-f27a-42e2-a685-0861f5cc34d8], (This step will run and generate new outputs)
#
# Created step discount_scoring [97d6b302][e08f36ff-331d-4a98-8445-6ea6f038248d], (This step will run and generate new outputs)
#
#
# Created step prediction_scoring_847 [ceb1f157][4421c276-71eb-47a6-a054-e07b7d557186], (This step will run and generate new outputs)
# Created step discount_scoring [07e90700][01741a85-f908-4ff4-85fb-41c4e610613c], (This step will run and generate new outputs)
#
# Created step prediction_scoring_859 [88a0fd66][492f1d2e-876a-4d96-97ba-25c98a0bb9b8], (This step will run and generate new outputs)
# Created step discount_scoring [e927c244][81bc1116-f926-40e5-be25-f95f907c58b4], (This step will run and generate new outputs)
# Created step prediction_scoring_805 [cb98b43c][0dfd409a-23e5-4253-9836-49e8709c4919], (This step will run and generate new outputs)
# Created step discount_scoring [227e2bc0][27b800eb-a7a8-4f39-9842-85b9661471ef], (This step will run and generate new outputs)
# Created step prediction_scoring_780 [d6bd141a][e52310ef-cd98-45ef-a1e4-5364c2ef621a], (This step will run and generate new outputs)
# Created step discount_scoring [e3ecb271][23454e53-6bca-4394-a344-a2aee1dbaa5b], (This step will run and generate new outputs)
# Created step prediction_scoring_782 [7e18444d][fa3d0d1c-c926-46f1-9399-d252c2bdab6a], (This step will run and generate new outputs)
# Created step discount_scoring [e2baffab][5913e32c-9e62-47f8-bafc-242b4bb37b09], (This step will run and generate new outputs)
# Created step prediction_scoring_781 [c4f003d9][8d80d561-1bca-481a-9239-ce556273e42a], (This step will run and generate new outputs)
# Created step discount_scoring [5e3daafc][2ef510d4-c245-4aa2-b5ee-3d28612237f9], (This step will run and generate new outputs)
# Created step prediction_scoring_773 [10ab8f71][21072d2b-62dd-47f3-92b2-f30f209821e9], (This step will run and generate new outputs)
# Created step discount_scoring [43c02258][ce154ce2-5001-4e7c-8609-c6d5a1099798], (This step will run and generate new outputs)
# Created step prediction_scoring_764 [d49b2b52][d07ee1d3-cc06-41ec-b6e5-0b095303bdef], (This step will run and generate new outputs)
# Created step discount_scoring [30291430][1e628c94-b01d-4441-9340-24262123726c], (This step will run and generate new outputs)
# Created step prediction_scoring_746 [b4ef09e4][b0ee3556-fb73-4f50-ab6a-b51535ca7700], (This step will run and generate new outputs)
# Created step discount_scoring [4959b879][a1c8c0f3-02d6-4d21-95a7-7efcb124696f], (This step will run and generate new outputs)
# Created step prediction_scoring_768 [9456527d][ef7159a8-d936-4400-a786-d86830724af1], (This step will run and generate new outputs)
# Created step discount_scoring [de22caa5][19d57f19-bfe8-422c-9139-9e89f30b4127], (This step will run and generate new outputs)
# Created step prediction_scoring_741 [8e0c1b4b][2ae3f325-b2c7-40e0-a7a3-d3ea857bc7c6], (This step will run and generate new outputs)
# Created step discount_scoring [d48c733b][cf0caa6f-818c-4442-bb3e-2faa4ab5638c], (This step will run and generate new outputs)
# Created step prediction_scoring_726 [e997e992][1bfb3e3b-2643-47d5-9fda-eb7355e283e2], (This step will run and generate new outputs)Created step discount_scoring [c2943dc0][6b22b037-a643-4c62-bbf6-9d307f79d8f5], (This step will run and generate new outputs)
# Created step prediction_scoring_711 [5baa50e8][0b55da4b-87cb-4492-a6b3-ffa998175f3e], (This step will run and generate new outputs)
# Created step discount_scoring [82d582ff][0dc575bd-5685-4410-8296-9ce09b908721], (This step will run and generate new outputs)Created step prediction_scoring_713 [8cca9402][2e5ebffa-33a0-478d-8f97-1626b03aa4b8], (This step will run and generate new outputs)
# Created step discount_scoring [bf9ee189][3f893328-221e-418d-a633-39d3c6365cb0], (This step will run and generate new outputs)
# Created step prediction_scoring_712 [6e9d58c5][7f620f2c-828a-439f-b28a-c0e61ed5852b], (This step will run and generate new outputs)
# Created step discount_scoring [bcd8d580][0a98b2e7-a466-41f7-ba80-f218fb9e866c], (This step will run and generate new outputs)Created step prediction_scoring_701 [6d7672cc][80e14c86-f777-49a7-8502-bdaa9a8dd821], (This step will run and generate new outputs)
# Created step discount_scoring [335bd26a][55254de1-2932-49f2-8f9d-9d183c91a695], (This step will run and generate new outputs)
#
#
# Created step prediction_scoring_685 [df6b0157][17a74aa0-b661-480a-a841-d0a999852e20], (This step will run and generate new outputs)
# Created step discount_scoring [b1d427f9][d1d8bf22-e8cd-43a3-8e46-a2398029cd3f], (This step will run and generate new outputs)Created step prediction_scoring_1419 [9abd999b][79715ceb-a181-4e2f-b580-edebd0354e4e], (This step will run and generate new outputs)
# Created step discount_scoring [0f7b9113][e5a30d3c-d4a4-44d7-b038-fd6d7966ca9a], (This step will run and generate new outputs)
# Created step prediction_scoring_681 [dbe08a22][9c8265a0-028c-469b-909e-48fd97792e25], (This step will run and generate new outputs)
# Created step discount_scoring [7cc10144][720861ec-5e0d-4efc-8d4e-45b7c5c13b7a], (This step will run and generate new outputs)
# Created step prediction_scoring_670 [bdc0a89d][9b2955ec-ebf7-43f6-904c-9eb04da09397], (This step will run and generate new outputs)Created step discount_scoring [2be6ddf0][55798d48-47f2-43cf-b38e-68590ad3573d], (This step will run and generate new outputs)
# Created step prediction_scoring_653 [31e9420e][2d17a0cd-3dbe-4455-89bc-59d7103f72f5], (This step will run and generate new outputs)
# Created step discount_scoring [d529c5ac][42604a09-a1b7-46d7-b0f0-d8b6c32983af], (This step will run and generate new outputs)Created step prediction_scoring_655 [8b8e9020][e95d135a-fe91-4e02-baca-305087ace014], (This step will run and generate new outputs)
# Created step discount_scoring [daabea53][cd9b08ba-73c3-4a8c-a525-b87392f180e7], (This step will run and generate new outputs)
# Created step prediction_scoring_1435 [4f7ec82e][ade5e906-3296-4248-9cfc-1ba30b09bfd8], (This step will run and generate new outputs)
# Created step discount_scoring [6e6377d8][571479a5-99ae-4c7e-b20d-be546eb17620], (This step will run and generate new outputs)
#
# Created step prediction_scoring_1160 [60c1ed3b][ed34f479-e844-408f-90f0-99c03aedce45], (This step will run and generate new outputs)
# Created step discount_scoring [cb4f7ccc][42afc152-4ca7-4f26-9ca1-4f12a4bbbcf4], (This step will run and generate new outputs)
# Created step prediction_scoring_599 [70316d5b][679a8397-5f5e-483f-abd4-46eb6c7e71a8], (This step will run and generate new outputs)
# Created step discount_scoring [c2b0ca01][e2cf0f20-b867-4e4f-97b3-bb6dfa9d7606], (This step will run and generate new outputs)
# Created step prediction_scoring_598 [976adcb3][0c4b39f7-4e42-4d54-b752-e227dc41b95a], (This step will run and generate new outputs)
# Created step discount_scoring [d8aafe9d][95333b79-a1cb-4ab1-b120-9efbfc7cff13], (This step will run and generate new outputs)
# Created step prediction_scoring_1175 [437be476][3c39110d-cd29-446e-b757-14b16c2bec0b], (This step will run and generate new outputs)
# Created step discount_scoring [1cbbf173][6e92b3bc-b9d5-4f4c-9239-139674a13b75], (This step will run and generate new outputs)
# Created step prediction_scoring_570 [a8305fad][ce97c609-c3d1-4ed2-9beb-dcf9816177c1], (This step will run and generate new outputs)
# Created step discount_scoring [18adf5a5][502a1f8e-77e1-4dcd-a449-c1a3ac2f344b], (This step will run and generate new outputs)
# Created step prediction_scoring_571 [d9a0113f][8d26977a-8c93-4795-854b-1cd052567c1d], (This step will run and generate new outputs)Created step discount_scoring [975e0bfb][3ca8993c-72d6-4ffd-a99a-7ede5eaac343], (This step will run and generate new outputs)
# Created step prediction_scoring_922 [0cc06cb7][45f5d61f-68ba-4150-86db-af399a7d4bab], (This step will run and generate new outputs)
# Created step discount_scoring [c49f76b8][095e6d90-2981-47d9-8428-4a81a3527cde], (This step will run and generate new outputs)
#
#
#
#
# Newly published pipeline id: 7233dbcd-f761-449c-97fa-8e41a3ed605a

# %% [markdown]
# # Запуск пайплайна с ноутбука

# %%
from azureml.core.authentication import InteractiveLoginAuthentication
import requests

rest_endpoint = published_pipeline.endpoint
interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

response = requests.post(rest_endpoint,
                         headers=auth_header,
                         json={"ExperimentName": "Prediction_pipeline"})
run_id = response.json()["Id"]
print(run_id)
# Out:
# 41b8e8ed-aa4b-4c0c-b5fe-919d3dd918d6

# %% [markdown]
# # Поставить пайплайн на расписание

# %%
published_pipeline.id
# Out:
# '8c65babd-e502-4d17-a506-6fab4fdd6a07'

# %%
from azureml.pipeline.core.schedule import ScheduleRecurrence, Schedule

recurrence = ScheduleRecurrence(frequency="Week", interval=1, 
                                week_days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"],
                                hours=[12], minutes=[10]) 


schedule = Schedule.create(workspace=ws, name="Forecasting_Schedule",
                           pipeline_id='{}'.format(published_pipeline.id), 
                           experiment_name="Prediction_pipeline",
                           recurrence=recurrence,
                           wait_for_provisioning=True,
                           description="Schedule Run")

# You may want to make sure that the schedule is provisioned properly
# before making any further changes to the schedule

print("Created schedule with id: {}".format(schedule.id))
# Out:
# Provisioning status: Completed
# Created schedule with id: 85e5dc56-7d57-415c-8b14-4cb63887a89f

# %%
from azureml.pipeline.core.schedule import ScheduleRecurrence, Schedule

recurrence = ScheduleRecurrence(frequency="Week", interval=1, 
                                week_days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"],
                                hours=[0], minutes=[10]) 


schedule = Schedule.create(workspace=ws, name="Forecasting_Schedule",
                           pipeline_id='02d69225-86a1-40fe-9d11-6699183702e0', 
                           experiment_name="Prediction_pipeline",
                           recurrence=recurrence,
                           wait_for_provisioning=True,
                           description="Schedule Run")

# You may want to make sure that the schedule is provisioned properly
# before making any further changes to the schedule

print("Created schedule with id: {}".format(schedule.id))
# Out:
# Provisioning status: Completed
# Created schedule with id: 8377260a-2ec2-4239-9a81-085444285bf5

# %% [markdown]
# # Посмотреть активные расписания и отключить какое-то, если необходимо

# %%
from azureml.pipeline.core.schedule import ScheduleRecurrence, Schedule
schedules = Schedule.list(ws, active_only=True)

# %%
# aee710f1-d0bb-4d19-9ed4-063d29b44b5d
schedules
# Out:
# [Pipeline(Name: Forecasting_Schedule,
#  Id: 8377260a-2ec2-4239-9a81-085444285bf5,
#  Status: Active,
#  Pipeline Id: 02d69225-86a1-40fe-9d11-6699183702e0,
#  Pipeline Endpoint Id: None,
#  Recurrence Details: Runs at 0:10 on Monday, Tuesday, Wednesday, Thursday, Friday, Saturday every Week)]

# %%
fetched_schedule = Schedule.get(ws, '{}'.format('8377260a-2ec2-4239-9a81-085444285bf5'))
fetched_schedule.disable()

# %% [markdown]
# # Проверить обновление магазинов

# %%
# %%time

from datetime import datetime, timedelta

blob_list = list(block_blob_service.list_blob_names('spardata', prefix = 'predictions/'))

blob_actual =  list(filter(lambda x: 'predictions/' in x, blob_list))
generator = block_blob_service.list_blobs(container_name)
prediction = []
for blob in blob_actual:
    lastModified= BlockBlobService.get_blob_properties(block_blob_service,'spardata',blob).properties.last_modified
    prediction.append([int(blob.split('/')[1]), lastModified + timedelta(hours = 3)])
    
prediction_df = pd.DataFrame(data = prediction, columns = ['store_id', 'last_updated_prediction'])
# Out:
# Wall time: 17.2 s

# %%
len(prediction_df[prediction_df['last_updated_prediction'] > '2022-09-05 15:00:00'].sort_values('last_updated_prediction', ascending = False))
# Out:
# 35

# %%
prediction_df[(prediction_df['last_updated_prediction'] > '2022-09-05 15:00:00')]
# Out:
#      store_id   last_updated_prediction
# 50       1346 2022-09-05 16:48:03+00:00
# 52       1348 2022-09-05 16:52:13+00:00
# 58       1354 2022-09-05 17:02:32+00:00
# 59       1356 2022-09-05 16:55:00+00:00
# 64       1361 2022-09-05 16:59:08+00:00
# 68       1372 2022-09-05 16:54:46+00:00
# 72       1378 2022-09-05 16:59:01+00:00
# 77       1384 2022-09-05 16:59:19+00:00
# 82       1393 2022-09-05 16:50:15+00:00
# 85       1396 2022-09-05 16:52:15+00:00
# 88       1399 2022-09-05 16:57:51+00:00
# 89       1403 2022-09-05 17:01:24+00:00
# 91       1405 2022-09-05 16:50:06+00:00
# 103      1431 2022-09-05 16:59:01+00:00
# 105      1433 2022-09-05 16:52:02+00:00
# 106      1434 2022-09-05 16:51:10+00:00
# 108      1436 2022-09-05 16:54:05+00:00
# 109      1437 2022-09-05 16:54:58+00:00
# 112      1442 2022-09-05 16:56:25+00:00
# 118      1465 2022-09-05 16:56:42+00:00
# 124      1478 2022-09-05 16:54:40+00:00
# 139      1554 2022-09-05 16:57:14+00:00
# 142      1568 2022-09-05 16:58:45+00:00
# 146      1596 2022-09-05 16:58:44+00:00
# 169       701 2022-09-05 16:47:57+00:00
# 170       711 2022-09-05 16:48:12+00:00
# 171       712 2022-09-05 16:54:22+00:00
# 172       713 2022-09-05 16:52:12+00:00
# 176       764 2022-09-05 16:59:40+00:00
# 185       846 2022-09-05 16:57:14+00:00
# 189       859 2022-09-05 16:54:47+00:00
# 193       874 2022-09-05 16:52:23+00:00
# 199       938 2022-09-05 16:59:11+00:00
# 201       956 2022-09-05 16:50:09+00:00
# 202       957 2022-09-05 16:47:23+00:00

# %%
prediction_df[prediction_df['last_updated_prediction'] > '2022-03-31 00:00:00'].sort_values('last_updated_prediction')
# Out:
#      store_id   last_updated_prediction
# 84       1395 2022-03-31 05:02:44+00:00
# 98       1417 2022-03-31 05:03:01+00:00
# 50       1346 2022-03-31 13:26:27+00:00
# 48       1338 2022-03-31 13:27:59+00:00
# 52       1348 2022-03-31 13:27:59+00:00
# ..        ...                       ...
# 169       741 2022-03-31 14:42:51+00:00
# 128      1509 2022-03-31 14:44:17+00:00
# 171       764 2022-03-31 14:47:42+00:00
# 172       768 2022-03-31 14:52:43+00:00
# 170       746 2022-03-31 14:57:30+00:00
#
# [116 rows x 2 columns]

# %%
prediction_df[prediction_df['store_id']==1418 ]
# Out:
#     store_id   last_updated_prediction
# 99      1418 2021-12-01 04:19:56+00:00

# %%
prediction_df[(prediction_df['last_updated_prediction'] > '2022-02-11 15:30:00')&
             (prediction_df['store_id'] == 1354)]
# Out:
#     store_id   last_updated_prediction
# 58      1354 2022-02-11 16:00:05+00:00

# %%
with io.BytesIO() as input_blob:
    block_blob_service.get_blob_to_stream(container_name='spardata',
                                          blob_name = f'predictions/{1399}/prediction.csv',
                                          stream = input_blob)
    input_blob.seek(0)
    prediction = pd.read_csv(input_blob)

# %%
prediction
# Out:
#               date    item_id  prediction
# 0       2022-03-16  100464321    0.000000
# 1       2022-03-17  100464321    0.000000
# 2       2022-03-18  100464321    0.000000
# 3       2022-03-19  100464321    0.000000
# 4       2022-03-20  100464321    0.000000
# ...            ...        ...         ...
# 626131  2022-04-22     124225   21.289082
# 626132  2022-04-23     124225   22.553281
# 626133  2022-04-24     124225   19.097876
# 626134  2022-04-25     124225   17.623722
# 626135  2022-04-26     124225   21.078643
#
# [626136 rows x 3 columns]

# %%
prediction
# Out:
#               date    item_id  prediction
# 0       2022-03-16  100589570         0.0
# 1       2022-03-17  100589570         0.0
# 2       2022-03-18  100589570         0.0
# 3       2022-03-19  100589570         0.0
# 4       2022-03-20  100589570         0.0
# ...            ...        ...         ...
# 166357  2022-04-22  101195855         0.0
# 166358  2022-04-23  101195855         0.0
# 166359  2022-04-24  101195855         0.0
# 166360  2022-04-25  101195855         0.0
# 166361  2022-04-26  101195855         0.0
#
# [166362 rows x 3 columns]

# %%
prediction[prediction['prediction'] > 0]
# Out:
#               date  item_id  prediction
# 504     2022-03-16   147058    5.000000
# 505     2022-03-17   147058    4.400000
# 506     2022-03-18   147058    2.200000
# 507     2022-03-19   147058    6.000000
# 508     2022-03-20   147058    3.000000
# ...            ...      ...         ...
# 166227  2022-04-18   103355    1.011674
# 166228  2022-04-19   103355    1.913150
# 166232  2022-04-23   103355    0.962875
# 166234  2022-04-25   103355    1.020614
# 166235  2022-04-26   103355    1.962869
#
# [57902 rows x 3 columns]
